# %% [markdown]
# <a href="https://colab.research.google.com/github/natyherreraa/Modulo0/blob/main/PracticaModulo0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd
import duckdb

# %%
df_ventas = pd.DataFrame({
    'id_venta': [1, 2, 3, 4, 5],
    'producto': ['Monitor 24"', 'Auriculares', 'Teclado', 'Laptop', 'Servidor'],
    'categoria': ['Monitores', 'Audio', 'Periféricos', 'Computadoras', 'Servidores'],
    'precio_unitario': [150.50, 80.00, 45.00, 800.00, 1000.00],
    'cantidad': [2, 1, 3, 1, 20],
    'fecha': ['2023-10-01', '2023-10-02', '2023-10-03', '2023-10-04', '2023-10-05'],
    'pais': ['Argentina', 'México', 'Colombia', 'Colombia', 'Argentina']
    })

# %%
# PUNTO 2 -- Consulta sobre productos y sus precios en orden ascendente alfabeticamente

SELECT producto, precio_unitario
FROM ventas_tecnologia
ORDER BY producto ASC;
# Out:
#   File "/tmp/ipykernel_1983/2962730776.py", line 3
#     SELECT producto, precio_unitario
#            ^
# SyntaxError: invalid syntax

# %%
# PUNTO 3 -- Ventas con valor mayor a 500 que se realizaron en pais especifico

SELECT *
FROM ventas_tecnologia
WHERE pais = 'Colombia' AND precio_unitario > 500;

# %%
# PUNTO 4 -- Identificacion de nulos para categoria
SELECT *
FROM ventas_tecnologia
WHERE categoria IS NULL;

# %%
#PUNTO 5 -- Cuánto dinero generó la empresa agrupado por cada categoría de producto
SELECT categoria, SUM(cantidad * precio_unitario) as ingresos_totales
FROM ventas_tecnologia
GROUP BY categoria;

# %%
# PUNTO 6 -- Categorias destacadas por su ingreso total
SELECT categoria, SUM(cantidad * precio_unitario) as ingresos_totales
FROM ventas_tecnologia
GROUP BY categoria
HAVING ingresos_totales > 10000;
# Out:
#   File "/tmp/ipykernel_1983/812231025.py", line 2
#     FROM ventas_tecnologia
#          ^
# SyntaxError: invalid syntax
